# %%
import datetime
from datetime import timedelta


# Example maps
map1 = {'43538438-0227-4580-9f85-70cd6286ef70': datetime.datetime(2023, 12, 6, 23, 45, 15, 709164), 'ab5b708a-0b94-4d3d-8d3c-c0757da51bd3': datetime.datetime(2023, 12, 6, 23, 45, 17, 789169), '4ef820cd-173d-4577-8198-0601f5c147ea': datetime.datetime(2023, 12, 6, 23, 45, 17, 873145), '31ee4875-855f-46e8-a2f9-a89c29f9f4a7': datetime.datetime(2023, 12, 6, 23, 45, 17, 905154), '7010b91c-6cbc-4fa4-8d23-1811ca3721a0': datetime.datetime(2023, 12, 6, 23, 45, 17, 985124), '3132b88d-8160-47dc-b058-8ab1dfeafbb4': datetime.datetime(2023, 12, 6, 23, 45, 18, 33127), '63b7784a-8ec5-4ada-989a-0bc5611ac068': datetime.datetime(2023, 12, 6, 23, 45, 18, 65124), 'a56e5943-9972-43c3-8a0c-8f9f90f28bc7': datetime.datetime(2023, 12, 6, 23, 45, 18, 113127), 'acb09228-2897-4f79-8ce1-d30e547267e5': datetime.datetime(2023, 12, 6, 23, 45, 18, 161129), 'e87892c6-493a-4e1d-bd86-5d2a24e79930': datetime.datetime(2023, 12, 6, 23, 45, 18, 193128), 'aaad3661-77fe-4863-99ff-cad955b6feb1': datetime.datetime(2023, 12, 6, 23, 45, 18, 241127), 'ddbe9a3c-1a6f-48fd-be2e-826abad3efcd': datetime.datetime(2023, 12, 6, 23, 45, 18, 293136), '6859d806-4ae4-4f0c-9dd8-7a82d220ce2e': datetime.datetime(2023, 12, 6, 23, 45, 18, 325129), '9aea83c7-be4c-4404-b5bb-798ef2687328': datetime.datetime(2023, 12, 6, 23, 45, 18, 381131), 'a8e30d66-41bd-4ea1-8f48-48266a03a9fc': datetime.datetime(2023, 12, 6, 23, 45, 18, 437126), 'e68eb38d-85bc-4210-a793-5589b86e38da': datetime.datetime(2023, 12, 6, 23, 45, 18, 477125), '44a8e8d2-f0cc-4723-b011-89602e647474': datetime.datetime(2023, 12, 6, 23, 45, 18, 525130), '6888844f-e872-4c8c-ae1a-4ae19682a68c': datetime.datetime(2023, 12, 6, 23, 45, 18, 581126), '11a51174-638d-47f2-ba5e-af5b28d6c66b': datetime.datetime(2023, 12, 6, 23, 45, 18, 629124), '3600134f-e904-41e5-8c2e-b0ccff6dc8a8': datetime.datetime(2023, 12, 6, 23, 45, 18, 685128), '33cb8493-de8b-4dca-8109-d18f4e28acbc': datetime.datetime(2023, 12, 6, 23, 45, 18, 741144), '0c4873ac-ad64-45a1-930a-0889f6b2e9bf': datetime.datetime(2023, 12, 6, 23, 45, 18, 781128), 'b35e6b26-0999-4a77-bf7f-db4f1b110059': datetime.datetime(2023, 12, 6, 23, 45, 18, 829124), 'adcb0ae6-0e05-4bd0-a5f8-6b8649cb46f2': datetime.datetime(2023, 12, 6, 23, 45, 18, 893127), '8b1ea473-2184-4f7b-bad8-b6012b6f4cbb': datetime.datetime(2023, 12, 6, 23, 45, 18, 933153), '5bc10f52-b02b-432c-a87a-6c13cf8d9c90': datetime.datetime(2023, 12, 6, 23, 45, 18, 989130), 'a743b667-ec60-4a60-a486-4917088969f4': datetime.datetime(2023, 12, 6, 23, 45, 19, 53128), '753f3d40-17d2-4148-991e-7411bfc70ce5': datetime.datetime(2023, 12, 6, 23, 45, 19,
ime.datetime(2023, 12, 6, 23, 45, 18, 317032), 'a56e5943-9972-43c3-8a0c-8f9f90f28bc7': datetime.datetime(2023, 12, 6, 23, 45, 18, 405579), 'acb09228-2897-4f79-8ce1-d30e547267e5': datetime.datetime(2023, 12, 6, 23, 45, 18, 488944), 'e87892c6-493a-4e1d-bd86-5d2a24e79930': datetime.datetime(2023, 12, 6, 23, 45, 18, 525242), 'aaad3661-77fe-4863-99ff-cad955b6feb1': datetime.datetime(2023, 12, 6, 23, 45, 18, 605326), 'ddbe9a3c-1a6f-48fd-be2e-826abad3efcd': datetime.datetime(2023, 12, 6, 23, 45, 18, 692748), '6859d806-4ae4-4f0c-9dd8-7a82d220ce2e': datetime.datetime(2023, 12, 6, 23, 45, 18, 733544), '9aea83c7-be4c-4404-b5bb-798ef2687328': datetime.datetime(2023, 12, 6, 23, 45, 18, 805159), 'a8e30d66-41bd-4ea1-8f48-48266a03a9fc': datetime.datetime(2023, 12, 6, 23, 45, 18, 901053), 'e68eb38d-85bc-4210-a793-5589b86e38da': datetime.datetime(2023, 12, 6, 23, 45, 18, 937085), '44a8e8d2-f0cc-4723-b011-89602e647474': datetime.datetime(2023, 12, 6, 23, 45, 19, 5292), '6888844f-e872-4c8c-ae1a-4ae19682a68c': datetime.datetime(2023, 12, 6, 23, 45, 19, 100810), '11a51174-638d-47f2-ba5e-af5b28d6c66b': datetime.datetime(2023, 12, 6, 23, 45, 19, 141497), '3600134f-e904-41e5-8c2e-b0ccff6dc8a8': datetime.datetime(2023, 12, 6, 23, 45, 19, 213394), '33cb8493-de8b-4dca-8109-d18f4e28acbc': datetime.datetime(2023, 12, 6, 23, 45, 19, 316783), '0c4873ac-ad64-45a1-930a-0889f6b2e9bf': datetime.datetime(2023, 12, 6, 23, 45, 19, 349544), 'b35e6b26-0999-4a77-bf7f-db4f1b110059': datetime.datetime(2023, 12, 6, 23, 45, 19, 417156), 'adcb0ae6-0e05-4bd0-a5f8-6b8649cb46f2': datetime.datetime(2023, 12, 6, 23, 45, 19, 521040), '8b1ea473-2184-4f7b-bad8-b6012b6f4cbb': datetime.datetime(2023, 12, 6, 23, 45, 19, 553146), '5bc10f52-b02b-432c-a87a-6c13cf8d9c90': datetime.datetime(2023, 12, 6, 23, 45, 19, 629283), 'a743b667-ec60-4a60-a486-4917088969f4': datetime.datetime(2023, 12, 6, 23, 45, 19, 724622), '753f3d40-17d2-4148-991e-7411bfc70ce5': datetime.datetime(2023, 12, 6, 23, 45, 19, 760937), 'e8a37b26-9590-42a9-afa4-c33f8e281566': datetime.datetime(2023, 12, 6, 23, 45, 19, 833356), '09428135-c9bb-44c5-a399-9a9c906afe6e': datetime.datetime(2023, 12, 6, 23, 45, 19, 925140), '7b0eb090-cacd-4e35-8b89-c8fb16d3b906': datetime.datetime(2023, 12, 6, 23, 45, 19, 968907), '7ad68851-298d-439d-bba1-d85fcc96d4d5': datetime.datetime(2023, 12, 6, 23, 45, 20, 37359), '52a38c9c-e5f3-446b-a2c5-67399200ec1c': datetime.datetime(2023, 12, 6, 23, 45, 20, 129007), 'efd94fdd-1d50-475f-b3df-87e49473ac08': datetime.datetime(2023, 12, 6, 23, 45, 20, 177066), '89d42bc5-3177-4c7d-873c-6df10cd7e75a': datetime.datetime(2023, 12, 6, 23, 45, 20, 245162), '04797276-1824-49a6-9ac9-2e065afa99f9': datetime.datetime(2023, 12, 6, 23, 45, 20, 333124), 'f5d8701c-e2fe-4d47-959e-5230fe75d9c7': datetime.datetime(2023, 12, 6, 23, 45, 20, 385357), 'db20b92c-d991-4c95-bf6c-281190ad84a0': datetime.datetime(2023, 12, 6, 23, 45, 20, 453241), '381a8e7f-7aa0-4ff0-85a1-fde270bda0a6': datetime.datetime(2023, 12, 6, 23, 45, 20, 536809), 'd4b87b03-959c-4aa2-8b66-39bf95d9552a': datetime.datetime(2023, 12, 6, 23, 45, 20, 589392), '2007dc7d-2777-4518-8fe9-b8e375668dab': datetime.datetime(2023, 12, 6, 23, 45, 20, 657525), 'd0512ac7-eab8-4f38-b9b8-b5f63e411631': datetime.datetime(2023, 12, 6, 23, 45, 20, 736991), 'bd9509eb-1c5a-43a0-a988-e25cf2cf5650': datetime.datetime(2023, 12, 6, 23, 45, 20, 793066), 'defcc802-0093-4a59-9750-d08826261033': datetime.datetime(2023, 12, 6, 23, 45, 20, 857537), '99303d5d-7365-4bfe-a1fe-290846e707bb': datetime.datetime(2023, 12, 6, 23, 45, 20, 937137), '6ab3911d-21b5-4867-b358-6ebe37e406a0': datetime.datetime(2023, 12, 6, 23, 45, 20, 993564), '345d58f3-832a-4f4f-96bb-15efc6a4d207': datetime.datetime(2023, 12, 6, 23, 45, 21, 57200), '47cc8d13-bef3-4b3b-83e5-c187c6dd1866': datetime.datetime(2023, 12, 6, 23, 45, 21, 140803), '0fc292e0-0c42-4022-9ca6-b50d61c66516': datetime.datetime(2023, 12, 6, 23, 45, 21, 196954), 'ce55e380-b211-4bd1-951e-f734fe174844': datetime.datetime(2023, 12, 6, 23, 45, 21, 257476)}

# Calculate time differences
time_differences = {}
for key, time1 in map1.items():
    if key in map2:
        time2 = map2[key]
        time_diff = time2 - time1
        time_differences[key] = time_diff

# Calculate the average time difference in milliseconds
total_diff_millis = 0
for diff in time_differences.values():
    total_diff_millis += diff.total_seconds() * 1000  # Convert to milliseconds

average_diff_millis = total_diff_millis / len(time_differences) if time_differences else 0

# Print the results
for key, diff in time_differences.items():
    diff_millis = diff.total_seconds() * 1000
    print(f"Time difference for key {key}: {diff_millis:.2f} milliseconds")

print(f"Average time difference: {average_diff_millis:.2f} milliseconds")
# Out:
# Time difference for key 43538438-0227-4580-9f85-70cd6286ef70: 204.56 milliseconds
# Time difference for key ab5b708a-0b94-4d3d-8d3c-c0757da51bd3: 208.40 milliseconds
# Time difference for key 4ef820cd-173d-4577-8198-0601f5c147ea: 203.81 milliseconds
# Time difference for key 31ee4875-855f-46e8-a2f9-a89c29f9f4a7: 204.31 milliseconds
# Time difference for key 7010b91c-6cbc-4fa4-8d23-1811ca3721a0: 216.32 milliseconds
# Time difference for key 3132b88d-8160-47dc-b058-8ab1dfeafbb4: 252.13 milliseconds
# Time difference for key 63b7784a-8ec5-4ada-989a-0bc5611ac068: 251.91 milliseconds
# Time difference for key a56e5943-9972-43c3-8a0c-8f9f90f28bc7: 292.45 milliseconds
# Time difference for key acb09228-2897-4f79-8ce1-d30e547267e5: 327.81 milliseconds
# Time difference for key e87892c6-493a-4e1d-bd86-5d2a24e79930: 332.11 milliseconds
# Time difference for key aaad3661-77fe-4863-99ff-cad955b6feb1: 364.20 milliseconds
# ...
